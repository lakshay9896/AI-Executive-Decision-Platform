# %% [raw]
# AI-Executive-Decision-Platform/
# │
# ├── app/
# │   ├── streamlit_app.py
# │   ├── ui_theme.py
# │   └── pages/
# │       ├── 1_Executive_Overview.py
# │       ├── 2_Revenue_Intelligence.py
# │       ├── 3_Churn_Analytics.py
# │       ├── 4_Profit_Simulation.py
# │       ├── 5_AI_Strategic_Advisor.py
# │       └── 6_Model_Performance.py
# │
# ├── data/
# │   ├── customers.csv
# │   ├── monthly_summary.csv
# │   └── transactions.csv
# │
# ├── models/
# │   ├── revenue_model.pkl
# │   ├── churn_model.pkl
# │   └── profit_model.pkl
# │
# ├── notebooks/
# │   ├── 01_data_generation.ipynb
# │   ├── 02_revenue_forecasting.ipynb
# │   ├── 03_churn_prediction.ipynb
# │   └── 04_profit_model.ipynb
# │
# ├── requirements.txt
# ├── README.md
# └── architecture.png (optional diagram)
